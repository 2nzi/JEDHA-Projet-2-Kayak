# %%
import requests
import json
import xml.etree.ElementTree as ET

url = 'https://nominatim.openstreetmap.org/search'
url = 'https://nominatim.openstreetmap.org/search?addressdetails=1&q=bakery+in+berlin+wedding&format=jsonv2&limit=1'
url = 'https://nominatim.openstreetmap.org/search?q=17+Strada+Pictor+Alexandru+Romano%2C&format=geojson'
payload = {
    'format':'json',
    'city':'Bukarest'
}
# r = requests.get(url,params=payload)
r = requests.get(url)


r.json()
# Out:
# {'type': 'FeatureCollection',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'features': [{'type': 'Feature',
#    'properties': {'place_id': 51712658,
#     'osm_type': 'node',
#     'osm_id': 2846295644,
#     'place_rank': 30,
#     'category': 'place',
#     'type': 'house',
#     'importance': 9.99999999995449e-06,
#     'addresstype': 'place',
#     'name': '',
#     'display_name': '17, Strada Pictor Alexandru Romano, Cartierul Armenesc, Sector 2, București, 023964, România'},
#    'bbox': [26.1156689, 44.4354754, 26.1157689, 44.4355754],
#    'geometry': {'type': 'Point', 'coordinates': [26.1157189, 44.4355254]}}]}

# %%
import pandas as pd
cities = pd.DataFrame([
    "Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris", "Amiens", "Lille", "Strasbourg",
    "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon",
    "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille", "Aix en Provence", "Avignon", "Uzes",
    "Nimes", "Aigues Mortes", "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege", "Toulouse",
    "Montauban", "Biarritz", "Bayonne", "La Rochelle"
], columns=["city"])
cities = cities['city'].str.replace(' ','-')
cities.iloc[0]
# Out:
# 'Mont-Saint-Michel'

# %% [markdown]
# r.json()[0]  car il y a plusieurs villes avec le même nom, celle qui apparait en premier dans la liste (car c'est une liste) elle celle avec la clef 'importance' la plus élévée

# %%
import requests

def get_cities(city):
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "format": "json", #prendre geojson???
        "q": f"{city},France"
    }
    r = requests.get(url, params=params)
      
    return r.json()[0] 
     
get_cities('Nantes')
# Out:
# {'place_id': 250236127,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 59874,
#  'lat': '47.2186371',
#  'lon': '-1.5541362',
#  'class': 'boundary',
#  'type': 'administrative',
#  'place_rank': 16,
#  'importance': 0.6430886552278882,
#  'addresstype': 'city',
#  'name': 'Nantes',
#  'display_name': 'Nantes, Loire-Atlantique, Pays de la Loire, France métropolitaine, France',
#  'boundingbox': ['47.1805856', '47.2958583', '-1.6418115', '-1.4788443']}

# %%
# for city in cities:
#     display(get_cities(city))

# %%
MSM = get_cities(cities.iloc[0])
MSM.keys()
# Out:
# dict_keys(['place_id', 'licence', 'osm_type', 'osm_id', 'lat', 'lon', 'class', 'type', 'place_rank', 'importance', 'addresstype', 'name', 'display_name', 'boundingbox'])

# %%
with open("API_key.txt", "r") as file:
    # Read one line from the file
    API_key = str(file.readline())
print(API_key)

lat = '47.2186371'
lon = '-1.5541362'
part = 'current,minutely,hourly,alerts'
# part=''
url = f'https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&exclude={part}&appid={API_key}'

payload = {

}

r_weather = requests.get(url,params=payload)
r_weather.json()
# Out:
# 056dcf70de133b9968d2d5068fa7b833
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1711702800,
#    'main': {'temp': 284.27,
#     'feels_like': 283.76,
#     'temp_min': 283.76,
#     'temp_max': 284.27,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 990,
#     'humidity': 89,
#     'temp_kf': 0.51},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 6.7, 'deg': 219, 'gust': 10.95},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.86},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 09:00:00'},
#   {'dt': 1711713600,
#    'main': {'temp': 284.78,
#     'feels_like': 284.11,
#     'temp_min': 284.78,
#     'temp_max': 285.8,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 81,
#     'temp_kf': -1.02},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 8.56, 'deg': 226, 'gust': 11.91},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.34},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 12:00:00'},
#   {'dt': 1711724400,
#    'main': {'temp': 285.34,
#     'feels_like': 284.57,
#     'temp_min': 285.34,
#     'temp_max': 285.88,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 75,
#     'temp_kf': -0.54},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 7.48, 'deg': 214, 'gust': 9.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 15:00:00'},
#   {'dt': 1711735200,
#    'main': {'temp': 283.28,
#     'feels_like': 282.39,
#     'temp_min': 283.28,
#     'temp_max': 283.28,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 990,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 6.31, 'deg': 175, 'gust': 11.22},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 18:00:00'},
#   {'dt': 1711746000,
#    'main': {'temp': 281.72,
#     'feels_like': 279.93,
#     'temp_min': 281.72,
#     'temp_max': 281.72,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 991,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.03, 'deg': 248, 'gust': 7.62},
#    'visibility': 10000,
#    'pop': 0.31,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-29 21:00:00'},
#   {'dt': 1711756800,
#    'main': {'temp': 280.51,
#     'feels_like': 279.92,
#     'temp_min': 280.51,
#     'temp_max': 280.51,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 992,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.39, 'deg': 178, 'gust': 1.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-30 00:00:00'},
#   {'dt': 1711767600,
#    'main': {'temp': 279.78,
#     'feels_like': 277.87,
#     'temp_min': 279.78,
#     'temp_max': 279.78,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 991,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.65, 'deg': 177, 'gust': 2.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-30 03:00:00'},
#   {'dt': 1711778400,
#    'main': {'temp': 278.92,
#     'feels_like': 277.39,
#     'temp_min': 278.92,
#     'temp_max': 278.92,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 991,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.03, 'deg': 170, 'gust': 2.02},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 06:00:00'},
#   {'dt': 1711789200,
#    'main': {'temp': 283.38,
#     'feels_like': 282.57,
#     'temp_min': 283.38,
#     'temp_max': 283.38,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 992,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.65, 'deg': 145, 'gust': 3.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 09:00:00'},
#   {'dt': 1711800000,
#    'main': {'temp': 286.6,
#     'feels_like': 285.75,
#     'temp_min': 286.6,
#     'temp_max': 286.6,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 991,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 4.27, 'deg': 181, 'gust': 5.05},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.36},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 12:00:00'},
#   {'dt': 1711810800,
#    'main': {'temp': 285.91,
#     'feels_like': 285.17,
#     'temp_min': 285.91,
#     'temp_max': 285.91,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 991,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 6.39, 'deg': 157, 'gust': 7.82},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.91},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 15:00:00'},
#   {'dt': 1711821600,
#    'main': {'temp': 283.12,
#     'feels_like': 280.46,
#     'temp_min': 283.12,
#     'temp_max': 283.12,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 991,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 5.67, 'deg': 146, 'gust': 11.58},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.07},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 18:00:00'},
#   {'dt': 1711832400,
#    'main': {'temp': 280.48,
#     'feels_like': 277.45,
#     'temp_min': 280.48,
#     'temp_max': 280.48,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 991,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.89, 'deg': 118, 'gust': 12.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-30 21:00:00'},
#   {'dt': 1711843200,
#    'main': {'temp': 279.53,
#     'feels_like': 276.3,
#     'temp_min': 279.53,
#     'temp_max': 279.53,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 990,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 4.81, 'deg': 121, 'gust': 12.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-31 00:00:00'},
#   {'dt': 1711854000,
#    'main': {'temp': 278.87,
#     'feels_like': 276.06,
#     'temp_min': 278.87,
#     'temp_max': 278.87,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 989,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 3.71, 'deg': 121, 'gust': 10.82},
#    'visibility': 10000,
#    'pop': 0.93,
#    'rain': {'3h': 0.47},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-31 03:00:00'},
#   {'dt': 1711864800,
#    'main': {'temp': 277.87,
#     'feels_like': 274.81,
#     'temp_min': 277.87,
#     'temp_max': 277.87,
#     'pressure': 991,
#     'sea_level': 991,
#     'grnd_level': 988,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 3.76, 'deg': 97, 'gust': 9.5},
#    'visibility': 10000,
#    'pop': 0.94,
#    'rain': {'3h': 0.41},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 06:00:00'},
#   {'dt': 1711875600,
#    'main': {'temp': 284.21,
#     'feels_like': 283.56,
#     'temp_min': 284.21,
#     'temp_max': 284.21,
#     'pressure': 991,
#     'sea_level': 991,
#     'grnd_level': 987,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 5.01, 'deg': 124, 'gust': 8.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 09:00:00'},
#   {'dt': 1711886400,
#    'main': {'temp': 287.5,
#     'feels_like': 286.9,
#     'temp_min': 287.5,
#     'temp_max': 287.5,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 986,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 5.58, 'deg': 110, 'gust': 8.72},
#    'visibility': 6610,
#    'pop': 0.73,
#    'rain': {'3h': 0.73},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 12:00:00'},
#   {'dt': 1711897200,
#    'main': {'temp': 282.73,
#     'feels_like': 280.54,
#     'temp_min': 282.73,
#     'temp_max': 282.73,
#     'pressure': 988,
#     'sea_level': 988,
#     'grnd_level': 984,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.2, 'deg': 247, 'gust': 7.06},
#    'visibility': 7851,
#    'pop': 1,
#    'rain': {'3h': 5.89},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 15:00:00'},
#   {'dt': 1711908000,
#    'main': {'temp': 282.12,
#     'feels_like': 282.12,
#     'temp_min': 282.12,
#     'temp_max': 282.12,
#     'pressure': 987,
#     'sea_level': 987,
#     'grnd_level': 984,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.88, 'deg': 322, 'gust': 1.46},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.62},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 18:00:00'},
#   {'dt': 1711918800,
#    'main': {'temp': 281.54,
#     'feels_like': 280.05,
#     'temp_min': 281.54,
#     'temp_max': 281.54,
#     'pressure': 988,
#     'sea_level': 988,
#     'grnd_level': 985,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.52, 'deg': 289, 'gust': 4.27},
#    'visibility': 10000,
#    'pop': 0.25,
#    'rain': {'3h': 0.24},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-31 21:00:00'},
#   {'dt': 1711929600,
#    'main': {'temp': 281.73,
#     'feels_like': 278.44,
#     'temp_min': 281.73,
#     'temp_max': 281.73,
#     'pressure': 990,
#     'sea_level': 990,
#     'grnd_level': 987,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.45, 'deg': 259, 'gust': 12.13},
#    'visibility': 9580,
#    'pop': 1,
#    'rain': {'3h': 0.72},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-01 00:00:00'},
#   {'dt': 1711940400,
#    'main': {'temp': 282.23,
#     'feels_like': 278.37,
#     'temp_min': 282.23,
#     'temp_max': 282.23,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 990,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9, 'deg': 258, 'gust': 15.82},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.78},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-01 03:00:00'},
#   {'dt': 1711951200,
#    'main': {'temp': 281.91,
#     'feels_like': 277.8,
#     'temp_min': 281.91,
#     'temp_max': 281.91,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 993,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.65, 'deg': 254, 'gust': 16.51},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 06:00:00'},
#   {'dt': 1711962000,
#    'main': {'temp': 283.95,
#     'feels_like': 283.31,
#     'temp_min': 283.95,
#     'temp_max': 283.95,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 997,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.42, 'deg': 246, 'gust': 13.98},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.18},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 09:00:00'},
#   {'dt': 1711972800,
#    'main': {'temp': 285.63,
#     'feels_like': 284.89,
#     'temp_min': 285.63,
#     'temp_max': 285.63,
#     'pressure': 1002,
#     'sea_level': 1002,
#     'grnd_level': 998,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 10.64, 'deg': 244, 'gust': 14.27},
#    'visibility': 10000,
#    'pop': 0.88,
#    'rain': {'3h': 0.46},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 12:00:00'},
#   {'dt': 1711983600,
#    'main': {'temp': 285.67,
#     'feels_like': 285.04,
#     'temp_min': 285.67,
#     'temp_max': 285.67,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 1000,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 9.27, 'deg': 257, 'gust': 13.4},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.41},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 15:00:00'},
#   {'dt': 1711994400,
#    'main': {'temp': 283.1,
#     'feels_like': 279.73,
#     'temp_min': 283.1,
#     'temp_max': 283.1,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1004,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 29},
#    'wind': {'speed': 8.11, 'deg': 263, 'gust': 14.06},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.68},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 18:00:00'},
#   {'dt': 1712005200,
#    'main': {'temp': 281.48,
#     'feels_like': 278.52,
#     'temp_min': 281.48,
#     'temp_max': 281.48,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1007,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.32, 'deg': 261, 'gust': 12.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-01 21:00:00'},
#   {'dt': 1712016000,
#    'main': {'temp': 280.93,
#     'feels_like': 278.29,
#     'temp_min': 280.93,
#     'temp_max': 280.93,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1009,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.27, 'deg': 249, 'gust': 10.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-02 00:00:00'},
#   {'dt': 1712026800,
#    'main': {'temp': 280.25,
#     'feels_like': 278,
#     'temp_min': 280.25,
#     'temp_max': 280.25,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1010,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 3.27, 'deg': 229, 'gust': 8.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-02 03:00:00'},
#   {'dt': 1712037600,
#    'main': {'temp': 280.18,
#     'feels_like': 277.98,
#     'temp_min': 280.18,
#     'temp_max': 280.18,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1011,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 3.17, 'deg': 219, 'gust': 6.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 06:00:00'},
#   {'dt': 1712048400,
#    'main': {'temp': 284.79,
#     'feels_like': 284.15,
#     'temp_min': 284.79,
#     'temp_max': 284.79,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1012,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 5.08, 'deg': 229, 'gust': 7.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 09:00:00'},
#   {'dt': 1712059200,
#    'main': {'temp': 287.36,
#     'feels_like': 286.59,
#     'temp_min': 287.36,
#     'temp_max': 287.36,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 5.76, 'deg': 205, 'gust': 7.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 12:00:00'},
#   {'dt': 1712070000,
#    'main': {'temp': 284.6,
#     'feels_like': 284.02,
#     'temp_min': 284.6,
#     'temp_max': 284.6,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1010,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.52, 'deg': 202, 'gust': 10.97},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.49},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 15:00:00'},
#   {'dt': 1712080800,
#    'main': {'temp': 282.07,
#     'feels_like': 278.64,
#     'temp_min': 282.07,
#     'temp_max': 282.07,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1008,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.2, 'deg': 176, 'gust': 15.5},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.85},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 18:00:00'},
#   {'dt': 1712091600,
#    'main': {'temp': 282.98,
#     'feels_like': 279.73,
#     'temp_min': 282.98,
#     'temp_max': 282.98,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1007,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.49, 'deg': 196, 'gust': 14.19},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.08},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-02 21:00:00'},
#   {'dt': 1712102400,
#    'main': {'temp': 284.05,
#     'feels_like': 283.68,
#     'temp_min': 284.05,
#     'temp_max': 284.05,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1006,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.84, 'deg': 213, 'gust': 15.52},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.23},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-03 00:00:00'},
#   {'dt': 1712113200,
#    'main': {'temp': 284.84,
#     'feels_like': 284.55,
#     'temp_min': 284.84,
#     'temp_max': 284.84,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1005,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.91, 'deg': 221, 'gust': 14.89},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.72},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-03 03:00:00'},
#   {'dt': 1712124000,
#    'main': {'temp': 284.72,
#     'feels_like': 284.44,
#     'temp_min': 284.72,
#     'temp_max': 284.72,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1003,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.21, 'deg': 227, 'gust': 14.38},
#    'visibility': 4671,
#    'pop': 1,
#    'rain': {'3h': 6.27},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-03 06:00:00'}],
#  'city': {'id': 6434483,
#   'name': 'Nantes',
#   'coord': {'lat': 47.2186, 'lon': -1.5541},
#   'country': 'FR',
#   'population': 0,
#   'timezone': 3600,
#   'sunrise': 1711691427,
#   'sunset': 1711737062}}
