# %%
import requests
import json
import xml.etree.ElementTree as ET

url = 'https://nominatim.openstreetmap.org/search'
url = 'https://nominatim.openstreetmap.org/search?addressdetails=1&q=bakery+in+berlin+wedding&format=jsonv2&limit=1'
url = 'https://nominatim.openstreetmap.org/search?q=17+Strada+Pictor+Alexandru+Romano%2C&format=geojson'
payload = {
    'format':'json',
    'city':'Bukarest'
}
# r = requests.get(url,params=payload)
r = requests.get(url)


r.json()
# Out:
# {'type': 'FeatureCollection',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'features': [{'type': 'Feature',
#    'properties': {'place_id': 84432860,
#     'osm_type': 'node',
#     'osm_id': 2846295644,
#     'place_rank': 30,
#     'category': 'place',
#     'type': 'house',
#     'importance': 9.99999999995449e-06,
#     'addresstype': 'place',
#     'name': '',
#     'display_name': '17, Strada Pictor Alexandru Romano, Cartierul Armenesc, Sector 2, București, 023964, România'},
#    'bbox': [26.1156689, 44.4354754, 26.1157689, 44.4355754],
#    'geometry': {'type': 'Point', 'coordinates': [26.1157189, 44.4355254]}}]}

# %%
import pandas as pd
cities = pd.DataFrame([
    "Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris", "Amiens", "Lille", "Strasbourg",
    "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon",
    "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille", "Aix en Provence", "Avignon", "Uzes",
    "Nimes", "Aigues Mortes", "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege", "Toulouse",
    "Montauban", "Biarritz", "Bayonne", "La Rochelle"
], columns=["city"])
cities = cities['city'].str.replace(' ','-')
cities.iloc[0]
# Out:
# 'Mont-Saint-Michel'

# %% [markdown]
# r.json()[0]  car il y a plusieurs villes avec le même nom, celle qui apparait en premier dans la liste (car c'est une liste) elle celle avec la clef 'importance' la plus élévée

# %%
import requests

def get_cities(city):
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "format": "json", #prendre geojson???
        "q": f"{city},France"
    }
    r = requests.get(url, params=params)
      
    return r.json()[0] 
     
get_cities('Nantes')
# Out:
# {'place_id': 280001735,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 59874,
#  'lat': '47.2186371',
#  'lon': '-1.5541362',
#  'class': 'boundary',
#  'type': 'administrative',
#  'place_rank': 16,
#  'importance': 0.6430886552278882,
#  'addresstype': 'city',
#  'name': 'Nantes',
#  'display_name': 'Nantes, Loire-Atlantique, Pays de la Loire, France métropolitaine, France',
#  'boundingbox': ['47.1805856', '47.2958583', '-1.6418115', '-1.4788443']}

# %%
# for city in cities:
#     display(get_cities(city))

# %%
MSM = get_cities(cities.iloc[0])
MSM.keys()
# Out:
# dict_keys(['place_id', 'licence', 'osm_type', 'osm_id', 'lat', 'lon', 'class', 'type', 'place_rank', 'importance', 'addresstype', 'name', 'display_name', 'boundingbox'])

# %%
with open("API_key.txt", "r") as file:
    # Read one line from the file
    API_key = str(file.readline())

lat = '47.2186371'
lon = '-1.5541362'
part = 'current,minutely,hourly,alerts'
# part=''
url = f'https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&exclude={part}&appid={API_key}'

payload = {

}

r_weather = requests.get(url,params=payload)
r_weather.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1711659600,
#    'main': {'temp': 282.7,
#     'feels_like': 279.99,
#     'temp_min': 280.19,
#     'temp_max': 282.7,
#     'pressure': 990,
#     'sea_level': 990,
#     'grnd_level': 986,
#     'humidity': 84,
#     'temp_kf': 2.51},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 5.51, 'deg': 168, 'gust': 9.65},
#    'visibility': 6449,
#    'pop': 0.97,
#    'rain': {'3h': 0.89},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-28 21:00:00'},
#   {'dt': 1711670400,
#    'main': {'temp': 281.01,
#     'feels_like': 281.01,
#     'temp_min': 279.54,
#     'temp_max': 281.01,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 984,
#     'humidity': 90,
#     'temp_kf': 1.47},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 1.27, 'deg': 59, 'gust': 1.39},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.74},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-29 00:00:00'},
#   {'dt': 1711681200,
#    'main': {'temp': 279.78,
#     'feels_like': 279.78,
#     'temp_min': 279.78,
#     'temp_max': 279.78,
#     'pressure': 988,
#     'sea_level': 988,
#     'grnd_level': 984,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.73, 'deg': 192, 'gust': 0.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-29 03:00:00'},
#   {'dt': 1711692000,
#    'main': {'temp': 280.23,
#     'feels_like': 278.14,
#     'temp_min': 280.23,
#     'temp_max': 280.23,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 986,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.02, 'deg': 245, 'gust': 8.66},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 3.71},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 06:00:00'},
#   {'dt': 1711702800,
#    'main': {'temp': 283.87,
#     'feels_like': 283.14,
#     'temp_min': 283.87,
#     'temp_max': 283.87,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 989,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.59, 'deg': 226, 'gust': 12.97},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.49},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 09:00:00'},
#   {'dt': 1711713600,
#    'main': {'temp': 285.36,
#     'feels_like': 284.57,
#     'temp_min': 285.36,
#     'temp_max': 285.36,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 990,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 9.49, 'deg': 221, 'gust': 13.7},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.73},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 12:00:00'},
#   {'dt': 1711724400,
#    'main': {'temp': 285.25,
#     'feels_like': 284.5,
#     'temp_min': 285.25,
#     'temp_max': 285.25,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 991,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 8.82, 'deg': 223, 'gust': 12.44},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.4},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 15:00:00'},
#   {'dt': 1711735200,
#    'main': {'temp': 282.76,
#     'feels_like': 280.2,
#     'temp_min': 282.76,
#     'temp_max': 282.76,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 991,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 5.14, 'deg': 229, 'gust': 10.2},
#    'visibility': 10000,
#    'pop': 0.98,
#    'rain': {'3h': 0.3},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 18:00:00'},
#   {'dt': 1711746000,
#    'main': {'temp': 280.43,
#     'feels_like': 278.36,
#     'temp_min': 280.43,
#     'temp_max': 280.43,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 992,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.06, 'deg': 154, 'gust': 4.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-29 21:00:00'},
#   {'dt': 1711756800,
#    'main': {'temp': 279.44,
#     'feels_like': 276.98,
#     'temp_min': 279.44,
#     'temp_max': 279.44,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 993,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.34, 'deg': 178, 'gust': 6.28},
#    'visibility': 10000,
#    'pop': 0.49,
#    'rain': {'3h': 0.55},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-30 00:00:00'},
#   {'dt': 1711767600,
#    'main': {'temp': 279.09,
#     'feels_like': 276.59,
#     'temp_min': 279.09,
#     'temp_max': 279.09,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 994,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.29, 'deg': 169, 'gust': 4.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-30 03:00:00'},
#   {'dt': 1711778400,
#    'main': {'temp': 278.41,
#     'feels_like': 275.7,
#     'temp_min': 278.41,
#     'temp_max': 278.41,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 993,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 3.39, 'deg': 165, 'gust': 7.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 06:00:00'},
#   {'dt': 1711789200,
#    'main': {'temp': 283.16,
#     'feels_like': 282.49,
#     'temp_min': 283.16,
#     'temp_max': 283.16,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 994,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 6.12, 'deg': 154, 'gust': 8.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 09:00:00'},
#   {'dt': 1711800000,
#    'main': {'temp': 286.24,
#     'feels_like': 285.41,
#     'temp_min': 286.24,
#     'temp_max': 286.24,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 993,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 7.06, 'deg': 155, 'gust': 9.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 12:00:00'},
#   {'dt': 1711810800,
#    'main': {'temp': 286.92,
#     'feels_like': 286.18,
#     'temp_min': 286.92,
#     'temp_max': 286.92,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 992,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 6.07, 'deg': 156, 'gust': 8.07},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.78},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 15:00:00'},
#   {'dt': 1711821600,
#    'main': {'temp': 283.64,
#     'feels_like': 283.04,
#     'temp_min': 283.64,
#     'temp_max': 283.64,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 993,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 6.29, 'deg': 143, 'gust': 11.37},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.42},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-30 18:00:00'},
#   {'dt': 1711832400,
#    'main': {'temp': 281.75,
#     'feels_like': 279.3,
#     'temp_min': 281.75,
#     'temp_max': 281.75,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 992,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 4.28, 'deg': 98, 'gust': 9.04},
#    'visibility': 10000,
#    'pop': 0.72,
#    'rain': {'3h': 0.61},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-30 21:00:00'},
#   {'dt': 1711843200,
#    'main': {'temp': 280.76,
#     'feels_like': 277.92,
#     'temp_min': 280.76,
#     'temp_max': 280.76,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 991,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 4.61, 'deg': 104, 'gust': 11.01},
#    'visibility': 10000,
#    'pop': 0.47,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-31 00:00:00'},
#   {'dt': 1711854000,
#    'main': {'temp': 279,
#     'feels_like': 276.27,
#     'temp_min': 279,
#     'temp_max': 279,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 990,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 3.63, 'deg': 104, 'gust': 9.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-31 03:00:00'},
#   {'dt': 1711864800,
#    'main': {'temp': 278.64,
#     'feels_like': 275.9,
#     'temp_min': 278.64,
#     'temp_max': 278.64,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 988,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 29},
#    'wind': {'speed': 3.51, 'deg': 96, 'gust': 7.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 06:00:00'},
#   {'dt': 1711875600,
#    'main': {'temp': 284.08,
#     'feels_like': 283.47,
#     'temp_min': 284.08,
#     'temp_max': 284.08,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 988,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.42, 'deg': 101, 'gust': 5.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 09:00:00'},
#   {'dt': 1711886400,
#    'main': {'temp': 287.72,
#     'feels_like': 287.16,
#     'temp_min': 287.72,
#     'temp_max': 287.72,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 986,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.6, 'deg': 85, 'gust': 7.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 12:00:00'},
#   {'dt': 1711897200,
#    'main': {'temp': 281.69,
#     'feels_like': 277.62,
#     'temp_min': 281.69,
#     'temp_max': 281.69,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 985,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.19, 'deg': 176, 'gust': 13.91},
#    'visibility': 7583,
#    'pop': 1,
#    'rain': {'3h': 4.24},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 15:00:00'},
#   {'dt': 1711908000,
#    'main': {'temp': 282.97,
#     'feels_like': 281.27,
#     'temp_min': 282.97,
#     'temp_max': 282.97,
#     'pressure': 988,
#     'sea_level': 988,
#     'grnd_level': 984,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.31, 'deg': 157, 'gust': 7.03},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.87},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-31 18:00:00'},
#   {'dt': 1711918800,
#    'main': {'temp': 281.48,
#     'feels_like': 279.27,
#     'temp_min': 281.48,
#     'temp_max': 281.48,
#     'pressure': 988,
#     'sea_level': 988,
#     'grnd_level': 985,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.67, 'deg': 152, 'gust': 6.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-31 21:00:00'},
#   {'dt': 1711929600,
#    'main': {'temp': 280.45,
#     'feels_like': 278.68,
#     'temp_min': 280.45,
#     'temp_max': 280.45,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 985,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.63, 'deg': 145, 'gust': 5.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-01 00:00:00'},
#   {'dt': 1711940400,
#    'main': {'temp': 279.58,
#     'feels_like': 277.47,
#     'temp_min': 279.58,
#     'temp_max': 279.58,
#     'pressure': 990,
#     'sea_level': 990,
#     'grnd_level': 986,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.86, 'deg': 232, 'gust': 5.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-01 03:00:00'},
#   {'dt': 1711951200,
#    'main': {'temp': 282.29,
#     'feels_like': 279.55,
#     'temp_min': 282.29,
#     'temp_max': 282.29,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 989,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.31, 'deg': 252, 'gust': 12.36},
#    'visibility': 10000,
#    'pop': 0.34,
#    'rain': {'3h': 0.24},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 06:00:00'},
#   {'dt': 1711962000,
#    'main': {'temp': 283.54,
#     'feels_like': 283.04,
#     'temp_min': 283.54,
#     'temp_max': 283.54,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 994,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.12, 'deg': 269, 'gust': 13.93},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.11},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 09:00:00'},
#   {'dt': 1711972800,
#    'main': {'temp': 285.28,
#     'feels_like': 284.82,
#     'temp_min': 285.28,
#     'temp_max': 285.28,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 997,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.93, 'deg': 256, 'gust': 12.94},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.18},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 12:00:00'},
#   {'dt': 1711983600,
#    'main': {'temp': 285.18,
#     'feels_like': 284.66,
#     'temp_min': 285.18,
#     'temp_max': 285.18,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 999,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 10.42, 'deg': 251, 'gust': 14.16},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.83},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 15:00:00'},
#   {'dt': 1711994400,
#    'main': {'temp': 282.92,
#     'feels_like': 279.37,
#     'temp_min': 282.92,
#     'temp_max': 282.92,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1002,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 8.6, 'deg': 247, 'gust': 14.26},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.35},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-01 18:00:00'},
#   {'dt': 1712005200,
#    'main': {'temp': 281.51,
#     'feels_like': 278.1,
#     'temp_min': 281.51,
#     'temp_max': 281.51,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1005,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 6.61, 'deg': 257, 'gust': 13.53},
#    'visibility': 10000,
#    'pop': 0.47,
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-01 21:00:00'},
#   {'dt': 1712016000,
#    'main': {'temp': 281.04,
#     'feels_like': 278.23,
#     'temp_min': 281.04,
#     'temp_max': 281.04,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1007,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 4.71, 'deg': 254, 'gust': 11.57},
#    'visibility': 10000,
#    'pop': 0.56,
#    'rain': {'3h': 0.36},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-02 00:00:00'},
#   {'dt': 1712026800,
#    'main': {'temp': 280.44,
#     'feels_like': 277.89,
#     'temp_min': 280.44,
#     'temp_max': 280.44,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1008,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 23},
#    'wind': {'speed': 3.88, 'deg': 245, 'gust': 9.67},
#    'visibility': 10000,
#    'pop': 0.56,
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-04-02 03:00:00'},
#   {'dt': 1712037600,
#    'main': {'temp': 280.07,
#     'feels_like': 277.61,
#     'temp_min': 280.07,
#     'temp_max': 280.07,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1009,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 3.56, 'deg': 224, 'gust': 9.9},
#    'visibility': 10000,
#    'pop': 0.16,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 06:00:00'},
#   {'dt': 1712048400,
#    'main': {'temp': 284.8,
#     'feels_like': 284.16,
#     'temp_min': 284.8,
#     'temp_max': 284.8,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1010,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 5.92, 'deg': 239, 'gust': 9.05},
#    'visibility': 10000,
#    'pop': 0.21,
#    'rain': {'3h': 0.24},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 09:00:00'},
#   {'dt': 1712059200,
#    'main': {'temp': 285.8,
#     'feels_like': 285.11,
#     'temp_min': 285.8,
#     'temp_max': 285.8,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1009,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 7.12, 'deg': 221, 'gust': 9.39},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.15},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 12:00:00'},
#   {'dt': 1712070000,
#    'main': {'temp': 286.07,
#     'feels_like': 285.48,
#     'temp_min': 286.07,
#     'temp_max': 286.07,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1008,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.61, 'deg': 218, 'gust': 9.81},
#    'visibility': 10000,
#    'pop': 0.27,
#    'rain': {'3h': 0.27},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 15:00:00'},
#   {'dt': 1712080800,
#    'main': {'temp': 283.33,
#     'feels_like': 282.75,
#     'temp_min': 283.33,
#     'temp_max': 283.33,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1007,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.67, 'deg': 191, 'gust': 11.85},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.51},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-04-02 18:00:00'}],
#  'city': {'id': 2990969,
#   'name': 'Nantes',
#   'coord': {'lat': 47.2186, 'lon': -1.5541},
#   'country': 'FR',
#   'population': 277269,
#   'timezone': 3600,
#   'sunrise': 1711605148,
#   'sunset': 1711650579}}
